# %%
import pandas as pd
import numpy as np

from aicentro.session import Session
sacp_session = Session(verify=False)
from aicentro.framework.framework import BaseFramework as SacpFrm
sacp_framework = SacpFrm(session=sacp_session)

# %% [markdown]
# ## <b>학습데이터 불러오기</b>
# ---

# %%
df = pd.read_csv('TrainData.csv',delimiter=',')

# %%
df
# Out:
#       url_len  url_num_hyphens_dom  url_num_dom_token  url_path_len  \
# 0          15                    0                4.0           0.0
# 1          96                    0                3.0          82.0
# 2          12                    0                3.0           0.0
# 3          35                    0                3.0          18.0
# 4          38                    0                3.0          17.0
# ...       ...                  ...                ...           ...
# 6103       37                    0                3.0          24.0
# 6104       37                    0                3.0          24.0
# 6105       37                    0                3.0          24.0
# 6106       37                    0                3.0          24.0
# 6107       37                    0                3.0          24.0
#
#       url_filename_len  url_longest_dom_token_len  url_average_dom_token_len  \
# 0                    0                          3                   3.000000
# 1                   68                          6                   4.000000
# 2                    0                          5                   3.333333
# 3                   10                          7                   5.000000
# 4                   16                         12                   6.333333
# ...                ...                        ...                        ...
# 6103                12                          6                   3.666667
# 6104                12                          6                   3.666667
# 6105                12                          6                   3.666667
# 6106                12                          6                   3.666667
# 6107                12                          6                   3.666667
#
#       url_tld  url_domain_len  url_hostname_len  ...  html_num_tags('form')  \
# 0           0            15.0                15  ...                      0
# 1           1            14.0                14  ...                      0
# 2           0            12.0                12  ...                      1
# 3           1            17.0                17  ...                      0
# 4           1            21.0                21  ...                      0
# ...       ...             ...               ...  ...                    ...
# 6103        1            13.0                13  ...                      0
# 6104        1            13.0                13  ...                      0
# 6105        1            13.0                13  ...                      0
# 6106        1            13.0                13  ...                      0
# 6107        1            13.0                13  ...                      0
#
#       html_num_tags('a')  html_num_tags('small')  html_num_tags('span')  \
# 0                      0                       0                      0
# 1                      4                       0                      1
# 2                     62                       0                     47
# 3                     48                       0                     76
# 4                      0                       0                      1
# ...                  ...                     ...                    ...
# 6103                   0                       0                      0
# 6104                   0                       0                      0
# 6105                   0                       0                      0
# 6106                   0                       0                      0
# 6107                   0                       0                      0
#
#       html_num_tags('input')  html_num_tags('applet')  html_num_tags('img')  \
# 0                          0                        0                     0
# 1                          0                        0                     1
# 2                          1                        0                    81
# 3                          0                        0                     0
# 4                          0                        0                     3
# ...                      ...                      ...                   ...
# 6103                       0                        0                     0
# 6104                       0                        0                     0
# 6105                       0                        0                     0
# 6106                       0                        0                     0
# 6107                       0                        0                     0
#
#       html_num_tags('video')  html_num_tags('audio')  Result_v1
# 0                          0                       0     benign
# 1                          0                       0     benign
# 2                          1                       0     benign
# 3                          0                       0     benign
# 4                          0                       0     benign
# ...                      ...                     ...        ...
# 6103                       0                       0     benign
# 6104                       0                       0     benign
# 6105                       0                       0     benign
# 6106                       0                       0     benign
# 6107                       0                       0     benign
#
# [6108 rows x 44 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6108 entries, 0 to 6107
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url_len                    6108 non-null   int64
#  1   url_num_hyphens_dom        6108 non-null   int64
#  2   url_num_dom_token          6105 non-null   float64
#  3   url_path_len               6107 non-null   float64
#  4   url_filename_len           6108 non-null   int64
#  5   url_longest_dom_token_len  6108 non-null   int64
#  6   url_average_dom_token_len  6108 non-null   float64
#  7   url_tld                    6108 non-null   int64
#  8   url_domain_len             6105 non-null   float64
#  9   url_hostname_len           6108 non-null   int64
#  10  url_num_dots               6108 non-null   int64
#  11  url_num_underscores        6107 non-null   float64
#  12  url_num_equals             6107 non-null   float64
#  13  url_num_slashes            6107 non-null   float64
#  14  url_num_dash               6108 non-null   int64
#  15  url_num_semicolon          6108 non-null   int64
#  16  url_num_at                 6108 non-null   int64
#  17  url_num_percent            6108 non-null   int64
#  18  url_num_plus               6108 non-null   int64
#  19  url_query_len              6108 non-null   int64
#  20  url_num_query_para         6108 non-null   int64
#  21  url_ip_present             6108 non-null   int64
#  22  url_entropy                6108 non-null   float64
#  23  url_count_consonants       6108 non-null   int64
#  24  url_num_digits             6108 non-null   int64
#  25  url_chinese_present        6108 non-null   int64
#  26  url_port                   6108 non-null   int64
#  27  html_num_tags('iframe')    6108 non-null   int64
#  28  html_num_tags('script')    6108 non-null   int64
#  29  html_num_tags('embed')     6108 non-null   int64
#  30  html_num_tags('object')    6108 non-null   int64
#  31  html_num_tags('div')       6108 non-null   int64
#  32  html_num_tags('head')      6108 non-null   int64
#  33  html_num_tags('body')      6108 non-null   int64
#  34  html_num_tags('form')      6108 non-null   int64
#  35  html_num_tags('a')         6108 non-null   int64
#  36  html_num_tags('small')     6108 non-null   int64
#  37  html_num_tags('span')      6108 non-null   int64
#  38  html_num_tags('input')     6108 non-null   int64
#  39  html_num_tags('applet')    6108 non-null   int64
#  40  html_num_tags('img')       6108 non-null   int64
#  41  html_num_tags('video')     6108 non-null   int64
#  42  html_num_tags('audio')     6108 non-null   int64
#  43  Result_v1                  6108 non-null   object
# dtypes: float64(8), int64(35), object(1)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#            url_len  url_num_hyphens_dom  url_num_dom_token  url_path_len  \
# count  6108.000000          6108.000000        6105.000000   6107.000000
# mean     53.709070             0.413720           2.862408     28.479941
# std      82.141842             0.830238           0.769080     76.689496
# min       5.000000             0.000000           2.000000      0.000000
# 25%      24.000000             0.000000           2.000000      1.000000
# 50%      36.000000             0.000000           3.000000     12.000000
# 75%      55.000000             1.000000           3.000000     30.000000
# max    1837.000000            14.000000          12.000000   1816.000000
#
#        url_filename_len  url_longest_dom_token_len  url_average_dom_token_len  \
# count       6108.000000                6108.000000                6108.000000
# mean          15.638507                  12.198428                   6.813073
# std           69.214863                   7.638118                   3.442360
# min            0.000000                   2.000000                   1.500000
# 25%            0.000000                   7.000000                   4.333333
# 50%            6.000000                  10.000000                   6.000000
# 75%           12.000000                  16.000000                   8.500000
# max         1771.000000                  63.000000                  31.500000
#
#            url_tld  url_domain_len  url_hostname_len  ...  \
# count  6108.000000     6105.000000       6108.000000  ...
# mean      0.901441       20.353317         20.305501  ...
# std       0.298094        9.287801          9.313965  ...
# min       0.000000        4.000000          4.000000  ...
# 25%       1.000000       14.000000         14.000000  ...
# 50%       1.000000       17.000000         17.000000  ...
# 75%       1.000000       24.000000         24.000000  ...
# max       1.000000      109.000000        109.000000  ...
#
#        html_num_tags('body')  html_num_tags('form')  html_num_tags('a')  \
# count            6108.000000            6108.000000         6108.000000
# mean                1.016699               1.019810           65.520138
# std                 0.226136               1.456458          333.460714
# min                 0.000000               0.000000            0.000000
# 25%                 1.000000               0.000000            2.000000
# 50%                 1.000000               1.000000           16.000000
# 75%                 1.000000               1.000000           52.000000
# max                 3.000000              57.000000        13451.000000
#
#        html_num_tags('small')  html_num_tags('span')  html_num_tags('input')  \
# count             6108.000000            6108.000000             6108.000000
# mean                 0.142436              25.166667                5.577112
# std                  2.253323             241.011547               10.290290
# min                  0.000000               0.000000                0.000000
# 25%                  0.000000               0.000000                0.000000
# 50%                  0.000000               2.000000                3.000000
# 75%                  0.000000              16.000000                8.000000
# max                113.000000           16457.000000              349.000000
#
#        html_num_tags('applet')  html_num_tags('img')  html_num_tags('video')  \
# count                   6108.0           6108.000000             6108.000000
# mean                       0.0             13.848396                0.014571
# std                        0.0             51.091158                0.146853
# min                        0.0              0.000000                0.000000
# 25%                        0.0              1.000000                0.000000
# 50%                        0.0              3.000000                0.000000
# 75%                        0.0              9.000000                0.000000
# max                        0.0           1885.000000                4.000000
#
#        html_num_tags('audio')
# count             6108.000000
# mean                 0.022430
# std                  0.369973
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                 11.000000
#
# [8 rows x 43 columns]

# %% [markdown]
# ## <b>데이터 탐색/정제</b>

# %% [markdown]
# ### <b>Q1. 중복 데이터 제거</b>
# ---
#  - 중복된 행데이터 삭제

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6108 entries, 0 to 6107
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url_len                    6108 non-null   int64
#  1   url_num_hyphens_dom        6108 non-null   int64
#  2   url_num_dom_token          6105 non-null   float64
#  3   url_path_len               6107 non-null   float64
#  4   url_filename_len           6108 non-null   int64
#  5   url_longest_dom_token_len  6108 non-null   int64
#  6   url_average_dom_token_len  6108 non-null   float64
#  7   url_tld                    6108 non-null   int64
#  8   url_domain_len             6105 non-null   float64
#  9   url_hostname_len           6108 non-null   int64
#  10  url_num_dots               6108 non-null   int64
#  11  url_num_underscores        6107 non-null   float64
#  12  url_num_equals             6107 non-null   float64
#  13  url_num_slashes            6107 non-null   float64
#  14  url_num_dash               6108 non-null   int64
#  15  url_num_semicolon          6108 non-null   int64
#  16  url_num_at                 6108 non-null   int64
#  17  url_num_percent            6108 non-null   int64
#  18  url_num_plus               6108 non-null   int64
#  19  url_query_len              6108 non-null   int64
#  20  url_num_query_para         6108 non-null   int64
#  21  url_ip_present             6108 non-null   int64
#  22  url_entropy                6108 non-null   float64
#  23  url_count_consonants       6108 non-null   int64
#  24  url_num_digits             6108 non-null   int64
#  25  url_chinese_present        6108 non-null   int64
#  26  url_port                   6108 non-null   int64
#  27  html_num_tags('iframe')    6108 non-null   int64
#  28  html_num_tags('script')    6108 non-null   int64
#  29  html_num_tags('embed')     6108 non-null   int64
#  30  html_num_tags('object')    6108 non-null   int64
#  31  html_num_tags('div')       6108 non-null   int64
#  32  html_num_tags('head')      6108 non-null   int64
#  33  html_num_tags('body')      6108 non-null   int64
#  34  html_num_tags('form')      6108 non-null   int64
#  35  html_num_tags('a')         6108 non-null   int64
#  36  html_num_tags('small')     6108 non-null   int64
#  37  html_num_tags('span')      6108 non-null   int64
#  38  html_num_tags('input')     6108 non-null   int64
#  39  html_num_tags('applet')    6108 non-null   int64
#  40  html_num_tags('img')       6108 non-null   int64
#  41  html_num_tags('video')     6108 non-null   int64
#  42  html_num_tags('audio')     6108 non-null   int64
#  43  Result_v1                  6108 non-null   object
# dtypes: float64(8), int64(35), object(1)
# memory usage: 2.1+ MB

# %%
# 중복 데이터 제거 : drop_duplicates()
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5198 entries, 0 to 6102
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url_len                    5198 non-null   int64
#  1   url_num_hyphens_dom        5198 non-null   int64
#  2   url_num_dom_token          5195 non-null   float64
#  3   url_path_len               5197 non-null   float64
#  4   url_filename_len           5198 non-null   int64
#  5   url_longest_dom_token_len  5198 non-null   int64
#  6   url_average_dom_token_len  5198 non-null   float64
#  7   url_tld                    5198 non-null   int64
#  8   url_domain_len             5195 non-null   float64
#  9   url_hostname_len           5198 non-null   int64
#  10  url_num_dots               5198 non-null   int64
#  11  url_num_underscores        5197 non-null   float64
#  12  url_num_equals             5197 non-null   float64
#  13  url_num_slashes            5197 non-null   float64
#  14  url_num_dash               5198 non-null   int64
#  15  url_num_semicolon          5198 non-null   int64
#  16  url_num_at                 5198 non-null   int64
#  17  url_num_percent            5198 non-null   int64
#  18  url_num_plus               5198 non-null   int64
#  19  url_query_len              5198 non-null   int64
#  20  url_num_query_para         5198 non-null   int64
#  21  url_ip_present             5198 non-null   int64
#  22  url_entropy                5198 non-null   float64
#  23  url_count_consonants       5198 non-null   int64
#  24  url_num_digits             5198 non-null   int64
#  25  url_chinese_present        5198 non-null   int64
#  26  url_port                   5198 non-null   int64
#  27  html_num_tags('iframe')    5198 non-null   int64
#  28  html_num_tags('script')    5198 non-null   int64
#  29  html_num_tags('embed')     5198 non-null   int64
#  30  html_num_tags('object')    5198 non-null   int64
#  31  html_num_tags('div')       5198 non-null   int64
#  32  html_num_tags('head')      5198 non-null   int64
#  33  html_num_tags('body')      5198 non-null   int64
#  34  html_num_tags('form')      5198 non-null   int64
#  35  html_num_tags('a')         5198 non-null   int64
#  36  html_num_tags('small')     5198 non-null   int64
#  37  html_num_tags('span')      5198 non-null   int64
#  38  html_num_tags('input')     5198 non-null   int64
#  39  html_num_tags('applet')    5198 non-null   int64
#  40  html_num_tags('img')       5198 non-null   int64
#  41  html_num_tags('video')     5198 non-null   int64
#  42  html_num_tags('audio')     5198 non-null   int64
#  43  Result_v1                  5198 non-null   object
# dtypes: float64(8), int64(35), object(1)
# memory usage: 1.8+ MB

# %% [markdown]
# ### <b>Q2. 텍스트와 범주형 특성 처리</b>
# ---
#  - replace() 함수를 이용한 텍스트와 범주형 특성 처리
#  - 참고사이트 : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
#
# #### <b>replace() 함수 사용 예</b>
# ---

# %%
import pandas as pd

df_ex = pd.DataFrame({'name': ['Alice','Bob','Charlie','Dave','Ellen','Frank'],
                   'age': [24,42,18,68,24,30],
                   'state': ['NY','CA','CA','TX','CA','NY'],
                   'point': [64,24,70,70,88,57]}
                  )

print(df_ex)
# Out:
#       name  age state  point
# 0    Alice   24    NY     64
# 1      Bob   42    CA     24
# 2  Charlie   18    CA     70
# 3     Dave   68    TX     70
# 4    Ellen   24    CA     88
# 5    Frank   30    NY     57

# %%
df_ex['state'].replace({'CA':'California','NY':'NewYork'}, inplace=True)
print(df_ex)
# Out:
#       name  age       state  point
# 0    Alice   24     NewYork     64
# 1      Bob   42  California     24
# 2  Charlie   18  California     70
# 3     Dave   68          TX     70
# 4    Ellen   24  California     88
# 5    Frank   30     NewYork     57

# %% [markdown]
# #### <b>텍스트와 범주형 특성 처리 실습</b>
# ---

# %%
# unique() 유일한 값 확인
df['Result_v1'].unique()
# Out:
# array(['benign', 'malicious'], dtype=object)

# %%
# replace() 함수 사용
# 'benign'=1,'malicious'=-1 처리
df['Result_v1'].replace({'benign':1,'malicious':-1}, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df['Result_v1'].unique()
# Out:
# array([ 1, -1])

# %% [markdown]
# ### <b>Q3. 결측치 제거</b>
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5198 entries, 0 to 6102
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url_len                    5198 non-null   int64
#  1   url_num_hyphens_dom        5198 non-null   int64
#  2   url_num_dom_token          5195 non-null   float64
#  3   url_path_len               5197 non-null   float64
#  4   url_filename_len           5198 non-null   int64
#  5   url_longest_dom_token_len  5198 non-null   int64
#  6   url_average_dom_token_len  5198 non-null   float64
#  7   url_tld                    5198 non-null   int64
#  8   url_domain_len             5195 non-null   float64
#  9   url_hostname_len           5198 non-null   int64
#  10  url_num_dots               5198 non-null   int64
#  11  url_num_underscores        5197 non-null   float64
#  12  url_num_equals             5197 non-null   float64
#  13  url_num_slashes            5197 non-null   float64
#  14  url_num_dash               5198 non-null   int64
#  15  url_num_semicolon          5198 non-null   int64
#  16  url_num_at                 5198 non-null   int64
#  17  url_num_percent            5198 non-null   int64
#  18  url_num_plus               5198 non-null   int64
#  19  url_query_len              5198 non-null   int64
#  20  url_num_query_para         5198 non-null   int64
#  21  url_ip_present             5198 non-null   int64
#  22  url_entropy                5198 non-null   float64
#  23  url_count_consonants       5198 non-null   int64
#  24  url_num_digits             5198 non-null   int64
#  25  url_chinese_present        5198 non-null   int64
#  26  url_port                   5198 non-null   int64
#  27  html_num_tags('iframe')    5198 non-null   int64
#  28  html_num_tags('script')    5198 non-null   int64
#  29  html_num_tags('embed')     5198 non-null   int64
#  30  html_num_tags('object')    5198 non-null   int64
#  31  html_num_tags('div')       5198 non-null   int64
#  32  html_num_tags('head')      5198 non-null   int64
#  33  html_num_tags('body')      5198 non-null   int64
#  34  html_num_tags('form')      5198 non-null   int64
#  35  html_num_tags('a')         5198 non-null   int64
#  36  html_num_tags('small')     5198 non-null   int64
#  37  html_num_tags('span')      5198 non-null   int64
#  38  html_num_tags('input')     5198 non-null   int64
#  39  html_num_tags('applet')    5198 non-null   int64
#  40  html_num_tags('img')       5198 non-null   int64
#  41  html_num_tags('video')     5198 non-null   int64
#  42  html_num_tags('audio')     5198 non-null   int64
#  43  Result_v1                  5198 non-null   int64
# dtypes: float64(8), int64(36)
# memory usage: 1.8 MB

# %%
# 결측치 제거
# dropna()

df = df.dropna(axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5189 entries, 0 to 5999
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url_len                    5189 non-null   int64
#  1   url_num_hyphens_dom        5189 non-null   int64
#  2   url_num_dom_token          5189 non-null   float64
#  3   url_path_len               5189 non-null   float64
#  4   url_filename_len           5189 non-null   int64
#  5   url_longest_dom_token_len  5189 non-null   int64
#  6   url_average_dom_token_len  5189 non-null   float64
#  7   url_tld                    5189 non-null   int64
#  8   url_domain_len             5189 non-null   float64
#  9   url_hostname_len           5189 non-null   int64
#  10  url_num_dots               5189 non-null   int64
#  11  url_num_underscores        5189 non-null   float64
#  12  url_num_equals             5189 non-null   float64
#  13  url_num_slashes            5189 non-null   float64
#  14  url_num_dash               5189 non-null   int64
#  15  url_num_semicolon          5189 non-null   int64
#  16  url_num_at                 5189 non-null   int64
#  17  url_num_percent            5189 non-null   int64
#  18  url_num_plus               5189 non-null   int64
#  19  url_query_len              5189 non-null   int64
#  20  url_num_query_para         5189 non-null   int64
#  21  url_ip_present             5189 non-null   int64
#  22  url_entropy                5189 non-null   float64
#  23  url_count_consonants       5189 non-null   int64
#  24  url_num_digits             5189 non-null   int64
#  25  url_chinese_present        5189 non-null   int64
#  26  url_port                   5189 non-null   int64
#  27  html_num_tags('iframe')    5189 non-null   int64
#  28  html_num_tags('script')    5189 non-null   int64
#  29  html_num_tags('embed')     5189 non-null   int64
#  30  html_num_tags('object')    5189 non-null   int64
#  31  html_num_tags('div')       5189 non-null   int64
#  32  html_num_tags('head')      5189 non-null   int64
#  33  html_num_tags('body')      5189 non-null   int64
#  34  html_num_tags('form')      5189 non-null   int64
#  35  html_num_tags('a')         5189 non-null   int64
#  36  html_num_tags('small')     5189 non-null   int64
#  37  html_num_tags('span')      5189 non-null   int64
#  38  html_num_tags('input')     5189 non-null   int64
#  39  html_num_tags('applet')    5189 non-null   int64
#  40  html_num_tags('img')       5189 non-null   int64
#  41  html_num_tags('video')     5189 non-null   int64
#  42  html_num_tags('audio')     5189 non-null   int64
#  43  Result_v1                  5189 non-null   int64
# dtypes: float64(8), int64(36)
# memory usage: 1.8 MB

# %% [markdown]
# ### <b>Q4. 데이터 탐색을 통한 불필요한 칼럼 제거</b>
# ---
# - ex) 그래프, 데이터 상관관계 corr()등 활용
# - corr() 메서드 : 모든 특성 간의 표준 상관계수(피어슨의 R)
#   - 확률론과 통계학에서 두 변수간에 어떤 선형적 또는 비선형적 관계를 갖고 있는지를 분석하는 방법
#   - r 값은 X 와 Y 가 완전히 동일하면 +1, 전혀 다르면 0, 반대방향으로 완전히 동일 하면 –1
# - scatter 그래프를 활용한 데이터 분석

# %% [markdown]
# #### <b>corr() 함수 사용 예</b>
# ---

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df_ex = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df_ex['target'] = iris.target

# %%
df_ex
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %%
df_ex.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
df_ex.corr()['target'].sort_values(ascending=False)
# Out:
# target               1.000000
# petal width (cm)     0.956547
# petal length (cm)    0.949035
# sepal length (cm)    0.782561
# sepal width (cm)    -0.426658
# Name: target, dtype: float64

# %% [markdown]
# #### <b>scatter 그래프를 활용한 데이터 분석 예</b>
# ---

# %%
import matplotlib.pyplot as plt

# %%
df_ex['color'] = df_ex['target'].map({0:"red", 1:"blue", 2:"green"})

# %%
df_ex
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target  color
# 0         0    red
# 1         0    red
# 2         0    red
# 3         0    red
# 4         0    red
# ..      ...    ...
# 145       2  green
# 146       2  green
# 147       2  green
# 148       2  green
# 149       2  green
#
# [150 rows x 6 columns]

# %%
y_list = df_ex.columns

for i in range(0, len(y_list)):
    df_ex.plot(kind='scatter',x='target',y=y_list[i],s=30, c=df_ex['color'])
    plt.title('Scatter', fontsize=20)
    plt.xlabel('target')
    plt.ylabel(y_list[i])
    plt.show()

# %% [markdown]
# #### <b>corr() 상관관계를 활용한 데이터 분석 실습</b>
# ---

# %%
df.corr()
# Out:
#                             url_len  url_num_hyphens_dom  url_num_dom_token  \
# url_len                    1.000000            -0.018826           0.007159
# url_num_hyphens_dom       -0.018826             1.000000          -0.099878
# url_num_dom_token          0.007159            -0.099878           1.000000
# url_path_len               0.928855            -0.094444          -0.004212
# url_filename_len           0.853502            -0.058208           0.019974
# url_longest_dom_token_len  0.009957             0.667767          -0.182165
# url_average_dom_token_len -0.005096             0.652332          -0.367355
# url_tld                    0.064684             0.138996          -0.307448
# url_domain_len             0.022298             0.591350           0.262989
# url_hostname_len           0.023144             0.592306           0.254906
# url_num_dots               0.252353            -0.077441           0.492296
# url_num_underscores        0.327331            -0.061190           0.032636
# url_num_equals             0.316038             0.001722          -0.052442
# url_num_slashes            0.337850            -0.151370          -0.069664
# url_num_dash               0.145194             0.567833          -0.073130
# url_num_semicolon          0.155763            -0.015652          -0.005302
# url_num_at                 0.081633            -0.017017          -0.026112
# url_num_percent            0.844000            -0.043415           0.003458
# url_num_plus               0.355150            -0.010456           0.002684
# url_query_len              0.362008             0.014533          -0.050377
# url_num_query_para         0.312997             0.010118          -0.057504
# url_ip_present            -0.057510            -0.126114           0.357396
# url_entropy                0.255898             0.079423           0.017442
# url_count_consonants       0.787162             0.027916          -0.014051
# url_num_digits             0.921763            -0.060163           0.018963
# url_chinese_present             NaN                  NaN                NaN
# url_port                   0.040297            -0.017902           0.032914
# html_num_tags('iframe')    0.040159            -0.035640           0.027773
# html_num_tags('script')   -0.019447            -0.124459           0.002689
# html_num_tags('embed')    -0.014543            -0.051506           0.011300
# html_num_tags('object')   -0.026314            -0.051207           0.033485
# html_num_tags('div')      -0.015859            -0.013117           0.001608
# html_num_tags('head')      0.051084             0.033541          -0.050552
# html_num_tags('body')      0.052018            -0.026045          -0.063316
# html_num_tags('form')     -0.021693             0.043228          -0.093271
# html_num_tags('a')        -0.021209            -0.038565           0.014906
# html_num_tags('small')    -0.009248            -0.020827          -0.010366
# html_num_tags('span')     -0.007828            -0.021724           0.004177
# html_num_tags('input')    -0.019711             0.116698          -0.043290
# html_num_tags('applet')         NaN                  NaN                NaN
# html_num_tags('img')      -0.026172            -0.016538           0.018720
# html_num_tags('video')    -0.028280            -0.020545          -0.026602
# html_num_tags('audio')    -0.010812            -0.005942          -0.007597
# Result_v1                 -0.005050            -0.362520           0.242202
#
#                            url_path_len  url_filename_len  \
# url_len                        0.928855          0.853502
# url_num_hyphens_dom           -0.094444         -0.058208
# url_num_dom_token             -0.004212          0.019974
# url_path_len                   1.000000          0.922102
# url_filename_len               0.922102          1.000000
# url_longest_dom_token_len     -0.099296         -0.061724
# url_average_dom_token_len     -0.113473         -0.075684
# url_tld                        0.035808          0.018670
# url_domain_len                -0.107595         -0.060335
# url_hostname_len              -0.106889         -0.060494
# url_num_dots                   0.163332          0.079096
# url_num_underscores            0.215426          0.191931
# url_num_equals                 0.019470         -0.009599
# url_num_slashes                0.320391          0.090043
# url_num_dash                   0.064474         -0.005672
# url_num_semicolon             -0.000275         -0.007861
# url_num_at                     0.010792          0.002859
# url_num_percent                0.906981          0.901693
# url_num_plus                   0.296874          0.327586
# url_query_len                  0.008753         -0.012271
# url_num_query_para             0.008639         -0.013823
# url_ip_present                -0.035206         -0.029973
# url_entropy                    0.130520          0.032331
# url_count_consonants           0.589779          0.462200
# url_num_digits                 0.933287          0.907636
# url_chinese_present                 NaN               NaN
# url_port                       0.045443          0.051245
# html_num_tags('iframe')        0.052799          0.058867
# html_num_tags('script')        0.012214          0.016763
# html_num_tags('embed')        -0.006515         -0.022625
# html_num_tags('object')       -0.019308         -0.024033
# html_num_tags('div')          -0.010389         -0.003106
# html_num_tags('head')          0.054291          0.054398
# html_num_tags('body')         -0.000953         -0.020830
# html_num_tags('form')         -0.031213         -0.036838
# html_num_tags('a')            -0.010427         -0.005430
# html_num_tags('small')        -0.003386         -0.001015
# html_num_tags('span')         -0.001565         -0.000507
# html_num_tags('input')        -0.045434         -0.035787
# html_num_tags('applet')             NaN               NaN
# html_num_tags('img')          -0.012145         -0.004678
# html_num_tags('video')        -0.026002         -0.014869
# html_num_tags('audio')        -0.009325         -0.012010
# Result_v1                      0.103433          0.118624
#
#                            url_longest_dom_token_len  \
# url_len                                     0.009957
# url_num_hyphens_dom                         0.667767
# url_num_dom_token                          -0.182165
# url_path_len                               -0.099296
# url_filename_len                           -0.061724
# url_longest_dom_token_len                   1.000000
# url_average_dom_token_len                   0.941963
# url_tld                                     0.276265
# url_domain_len                              0.858045
# url_hostname_len                            0.860118
# url_num_dots                               -0.142754
# url_num_underscores                        -0.094288
# url_num_equals                              0.015676
# url_num_slashes                            -0.117821
# url_num_dash                                0.379883
# url_num_semicolon                          -0.020425
# url_num_at                                 -0.002531
# url_num_percent                            -0.055236
# url_num_plus                                0.009674
# url_query_len                               0.026218
# url_num_query_para                          0.022242
# url_ip_present                             -0.265351
# url_entropy                                 0.142769
# url_count_consonants                        0.099257
# url_num_digits                             -0.061490
# url_chinese_present                              NaN
# url_port                                   -0.022645
# html_num_tags('iframe')                    -0.034977
# html_num_tags('script')                    -0.113857
# html_num_tags('embed')                     -0.041900
# html_num_tags('object')                    -0.057987
# html_num_tags('div')                       -0.013656
# html_num_tags('head')                       0.024101
# html_num_tags('body')                       0.059770
# html_num_tags('form')                       0.064505
# html_num_tags('a')                         -0.051552
# html_num_tags('small')                     -0.022676
# html_num_tags('span')                      -0.029898
# html_num_tags('input')                      0.131299
# html_num_tags('applet')                          NaN
# html_num_tags('img')                       -0.059097
# html_num_tags('video')                     -0.002912
# html_num_tags('audio')                     -0.008084
# Result_v1                                  -0.509985
#
#                            url_average_dom_token_len   url_tld  \
# url_len                                    -0.005096  0.064684
# url_num_hyphens_dom                         0.652332  0.138996
# url_num_dom_token                          -0.367355 -0.307448
# url_path_len                               -0.113473  0.035808
# url_filename_len                           -0.075684  0.018670
# url_longest_dom_token_len                   0.941963  0.276265
# url_average_dom_token_len                   1.000000  0.289709
# url_tld                                     0.289709  1.000000
# url_domain_len                              0.761543  0.171360
# url_hostname_len                            0.764301  0.184784
# url_num_dots                               -0.237913 -0.141541
# url_num_underscores                        -0.105003 -0.016250
# url_num_equals                              0.046237  0.043673
# url_num_slashes                            -0.121935  0.068768
# url_num_dash                                0.371777  0.110735
# url_num_semicolon                          -0.011444 -0.015724
# url_num_at                                  0.003304  0.013078
# url_num_percent                            -0.069006  0.023202
# url_num_plus                                0.005013  0.014193
# url_query_len                               0.051064  0.034748
# url_num_query_para                          0.052678  0.038123
# url_ip_present                             -0.284640 -0.716088
# url_entropy                                 0.129330  0.160146
# url_count_consonants                        0.085804  0.146579
# url_num_digits                             -0.071567 -0.001994
# url_chinese_present                              NaN       NaN
# url_port                                   -0.017856 -0.057530
# html_num_tags('iframe')                    -0.036174  0.010377
# html_num_tags('script')                    -0.110143  0.052717
# html_num_tags('embed')                     -0.029977  0.000669
# html_num_tags('object')                    -0.053328 -0.043249
# html_num_tags('div')                       -0.008157  0.023403
# html_num_tags('head')                       0.030163  0.008270
# html_num_tags('body')                       0.060992  0.033537
# html_num_tags('form')                       0.084927  0.066734
# html_num_tags('a')                         -0.050408  0.022512
# html_num_tags('small')                     -0.023859  0.015312
# html_num_tags('span')                      -0.029085  0.016413
# html_num_tags('input')                      0.144006  0.064137
# html_num_tags('applet')                          NaN       NaN
# html_num_tags('img')                       -0.049020  0.001630
# html_num_tags('video')                      0.001595 -0.001935
# html_num_tags('audio')                     -0.004599 -0.006469
# Result_v1                                  -0.534915 -0.195497
#
#                            url_domain_len  url_hostname_len  ...  \
# url_len                          0.022298          0.023144  ...
# url_num_hyphens_dom              0.591350          0.592306  ...
# url_num_dom_token                0.262989          0.254906  ...
# url_path_len                    -0.107595         -0.106889  ...
# url_filename_len                -0.060335         -0.060494  ...
# url_longest_dom_token_len        0.858045          0.860118  ...
# url_average_dom_token_len        0.761543          0.764301  ...
# url_tld                          0.171360          0.184784  ...
# url_domain_len                   1.000000          0.999038  ...
# url_hostname_len                 0.999038          1.000000  ...
# url_num_dots                     0.073303          0.070167  ...
# url_num_underscores             -0.081939         -0.082337  ...
# url_num_equals                   0.029423          0.030396  ...
# url_num_slashes                 -0.158727         -0.154507  ...
# url_num_dash                     0.332630          0.334176  ...
# url_num_semicolon               -0.014048         -0.013657  ...
# url_num_at                      -0.006068         -0.005634  ...
# url_num_percent                 -0.057954         -0.057850  ...
# url_num_plus                     0.014871          0.015067  ...
# url_query_len                    0.038750          0.039567  ...
# url_num_query_para               0.033541          0.034434  ...
# url_ip_present                  -0.156513         -0.174187  ...
# url_entropy                      0.168044          0.172311  ...
# url_count_consonants             0.114023          0.116567  ...
# url_num_digits                  -0.049297         -0.049681  ...
# url_chinese_present                   NaN               NaN  ...
# url_port                        -0.001347         -0.019860  ...
# html_num_tags('iframe')         -0.020954         -0.020242  ...
# html_num_tags('script')         -0.100056         -0.097395  ...
# html_num_tags('embed')          -0.013671         -0.012966  ...
# html_num_tags('object')         -0.031521         -0.033389  ...
# html_num_tags('div')            -0.002849         -0.001874  ...
# html_num_tags('head')           -0.004097         -0.004067  ...
# html_num_tags('body')            0.031301          0.031632  ...
# html_num_tags('form')            0.030835          0.033727  ...
# html_num_tags('a')              -0.035988         -0.034985  ...
# html_num_tags('small')          -0.026944         -0.026499  ...
# html_num_tags('span')           -0.024162         -0.023610  ...
# html_num_tags('input')           0.123565          0.125276  ...
# html_num_tags('applet')               NaN               NaN  ...
# html_num_tags('img')            -0.031024         -0.029755  ...
# html_num_tags('video')          -0.011716         -0.011680  ...
# html_num_tags('audio')          -0.003609         -0.004364  ...
# Result_v1                       -0.383381         -0.387142  ...
#
#                            html_num_tags('form')  html_num_tags('a')  \
# url_len                                -0.021693           -0.021209
# url_num_hyphens_dom                     0.043228           -0.038565
# url_num_dom_token                      -0.093271            0.014906
# url_path_len                           -0.031213           -0.010427
# url_filename_len                       -0.036838           -0.005430
# url_longest_dom_token_len               0.064505           -0.051552
# url_average_dom_token_len               0.084927           -0.050408
# url_tld                                 0.066734            0.022512
# url_domain_len                          0.030835           -0.035988
# url_hostname_len                        0.033727           -0.034985
# url_num_dots                           -0.072797           -0.032629
# url_num_underscores                    -0.075584           -0.009439
# url_num_equals                          0.009048           -0.024509
# url_num_slashes                         0.055055           -0.030864
# url_num_dash                            0.075893            0.072708
# url_num_semicolon                       0.012745           -0.009751
# url_num_at                             -0.005720           -0.011169
# url_num_percent                        -0.031241           -0.006223
# url_num_plus                            0.001329           -0.003522
# url_query_len                           0.011900           -0.021149
# url_num_query_para                      0.007408           -0.022615
# url_ip_present                         -0.083359           -0.035000
# url_entropy                            -0.017405           -0.031572
# url_count_consonants                   -0.022324           -0.030192
# url_num_digits                         -0.021692           -0.013360
# url_chinese_present                          NaN                 NaN
# url_port                               -0.010582           -0.005832
# html_num_tags('iframe')                 0.113333            0.043183
# html_num_tags('script')                 0.255588            0.110597
# html_num_tags('embed')                 -0.023497            0.014139
# html_num_tags('object')                 0.011888            0.059625
# html_num_tags('div')                    0.134412            0.712562
# html_num_tags('head')                   0.034620            0.004697
# html_num_tags('body')                   0.021358           -0.008614
# html_num_tags('form')                   1.000000            0.092852
# html_num_tags('a')                      0.092852            1.000000
# html_num_tags('small')                  0.043718            0.026639
# html_num_tags('span')                   0.053143            0.716248
# html_num_tags('input')                  0.779350            0.043381
# html_num_tags('applet')                      NaN                 NaN
# html_num_tags('img')                    0.118437            0.269481
# html_num_tags('video')                  0.056134            0.042146
# html_num_tags('audio')                  0.106033            0.024944
# Result_v1                              -0.124800            0.115747
#
#                            html_num_tags('small')  html_num_tags('span')  \
# url_len                                 -0.009248              -0.007828
# url_num_hyphens_dom                     -0.020827              -0.021724
# url_num_dom_token                       -0.010366               0.004177
# url_path_len                            -0.003386              -0.001565
# url_filename_len                        -0.001015              -0.000507
# url_longest_dom_token_len               -0.022676              -0.029898
# url_average_dom_token_len               -0.023859              -0.029085
# url_tld                                  0.015312               0.016413
# url_domain_len                          -0.026944              -0.024162
# url_hostname_len                        -0.026499              -0.023610
# url_num_dots                            -0.016543              -0.019283
# url_num_underscores                     -0.010894              -0.000603
# url_num_equals                          -0.010060              -0.011527
# url_num_slashes                          0.000605              -0.017382
# url_num_dash                            -0.012078               0.058075
# url_num_semicolon                       -0.003581              -0.004138
# url_num_at                              -0.004865              -0.003513
# url_num_percent                          0.002370              -0.000703
# url_num_plus                            -0.002781              -0.002166
# url_query_len                           -0.008824              -0.010531
# url_num_query_para                      -0.009092              -0.010346
# url_ip_present                          -0.012055              -0.021434
# url_entropy                             -0.043616              -0.022608
# url_count_consonants                    -0.020190              -0.012060
# url_num_digits                          -0.001805              -0.005492
# url_chinese_present                           NaN                    NaN
# url_port                                -0.002408              -0.002808
# html_num_tags('iframe')                  0.060016               0.025793
# html_num_tags('script')                  0.037782               0.068935
# html_num_tags('embed')                  -0.006161              -0.003268
# html_num_tags('object')                  0.028484               0.028279
# html_num_tags('div')                     0.029632               0.600261
# html_num_tags('head')                    0.004241               0.006338
# html_num_tags('body')                   -0.002417              -0.005521
# html_num_tags('form')                    0.043718               0.053143
# html_num_tags('a')                       0.026639               0.716248
# html_num_tags('small')                   1.000000               0.023750
# html_num_tags('span')                    0.023750               1.000000
# html_num_tags('input')                   0.029452               0.048975
# html_num_tags('applet')                       NaN                    NaN
# html_num_tags('img')                     0.083447               0.079203
# html_num_tags('video')                   0.024802               0.020863
# html_num_tags('audio')                   0.026609               0.002889
# Result_v1                                0.022192               0.053305
#
#                            html_num_tags('input')  html_num_tags('applet')  \
# url_len                                 -0.019711                      NaN
# url_num_hyphens_dom                      0.116698                      NaN
# url_num_dom_token                       -0.043290                      NaN
# url_path_len                            -0.045434                      NaN
# url_filename_len                        -0.035787                      NaN
# url_longest_dom_token_len                0.131299                      NaN
# url_average_dom_token_len                0.144006                      NaN
# url_tld                                  0.064137                      NaN
# url_domain_len                           0.123565                      NaN
# url_hostname_len                         0.125276                      NaN
# url_num_dots                            -0.016822                      NaN
# url_num_underscores                     -0.062728                      NaN
# url_num_equals                           0.015782                      NaN
# url_num_slashes                         -0.007141                      NaN
# url_num_dash                             0.076615                      NaN
# url_num_semicolon                        0.003348                      NaN
# url_num_at                              -0.007880                      NaN
# url_num_percent                         -0.036418                      NaN
# url_num_plus                            -0.003444                      NaN
# url_query_len                            0.026356                      NaN
# url_num_query_para                       0.020015                      NaN
# url_ip_present                          -0.054591                      NaN
# url_entropy                              0.009223                      NaN
# url_count_consonants                     0.002060                      NaN
# url_num_digits                          -0.031809                      NaN
# url_chinese_present                           NaN                      NaN
# url_port                                 0.009932                      NaN
# html_num_tags('iframe')                  0.105501                      NaN
# html_num_tags('script')                  0.152160                      NaN
# html_num_tags('embed')                  -0.044588                      NaN
# html_num_tags('object')                 -0.022149                      NaN
# html_num_tags('div')                     0.097036                      NaN
# html_num_tags('head')                    0.020787                      NaN
# html_num_tags('body')                   -0.010171                      NaN
# html_num_tags('form')                    0.779350                      NaN
# html_num_tags('a')                       0.043381                      NaN
# html_num_tags('small')                   0.029452                      NaN
# html_num_tags('span')                    0.048975                      NaN
# html_num_tags('input')                   1.000000                      NaN
# html_num_tags('applet')                       NaN                      NaN
# html_num_tags('img')                     0.058674                      NaN
# html_num_tags('video')                  -0.001743                      NaN
# html_num_tags('audio')                   0.021717                      NaN
# Result_v1                               -0.199075                      NaN
#
#                            html_num_tags('img')  html_num_tags('video')  \
# url_len                               -0.026172               -0.028280
# url_num_hyphens_dom                   -0.016538               -0.020545
# url_num_dom_token                      0.018720               -0.026602
# url_path_len                          -0.012145               -0.026002
# url_filename_len                      -0.004678               -0.014869
# url_longest_dom_token_len             -0.059097               -0.002912
# url_average_dom_token_len             -0.049020                0.001595
# url_tld                                0.001630               -0.001935
# url_domain_len                        -0.031024               -0.011716
# url_hostname_len                      -0.029755               -0.011680
# url_num_dots                          -0.037459               -0.042178
# url_num_underscores                    0.008164               -0.015655
# url_num_equals                        -0.036335               -0.010358
# url_num_slashes                       -0.055597               -0.058638
# url_num_dash                           0.013064               -0.027524
# url_num_semicolon                     -0.012048               -0.005977
# url_num_at                            -0.015822               -0.007119
# url_num_percent                       -0.001608               -0.009873
# url_num_plus                          -0.007425               -0.004069
# url_query_len                         -0.032133               -0.007397
# url_num_query_para                    -0.034372               -0.008171
# url_ip_present                        -0.022753               -0.019556
# url_entropy                           -0.022034               -0.063870
# url_count_consonants                  -0.033432               -0.034612
# url_num_digits                        -0.020452               -0.015502
# url_chinese_present                         NaN                     NaN
# url_port                              -0.006731               -0.003524
# html_num_tags('iframe')                0.094685               -0.004679
# html_num_tags('script')                0.137829                0.029595
# html_num_tags('embed')                 0.035760               -0.011374
# html_num_tags('object')                0.093200                0.392085
# html_num_tags('div')                   0.211104                0.039322
# html_num_tags('head')                 -0.001144               -0.000311
# html_num_tags('body')                  0.003970               -0.007160
# html_num_tags('form')                  0.118437                0.056134
# html_num_tags('a')                     0.269481                0.042146
# html_num_tags('small')                 0.083447                0.024802
# html_num_tags('span')                  0.079203                0.020863
# html_num_tags('input')                 0.058674               -0.001743
# html_num_tags('applet')                     NaN                     NaN
# html_num_tags('img')                   1.000000                0.076571
# html_num_tags('video')                 0.076571                1.000000
# html_num_tags('audio')                 0.000748                0.549091
# Result_v1                              0.139923                0.006198
#
#                            html_num_tags('audio')  Result_v1
# url_len                                 -0.010812  -0.005050
# url_num_hyphens_dom                     -0.005942  -0.362520
# url_num_dom_token                       -0.007597   0.242202
# url_path_len                            -0.009325   0.103433
# url_filename_len                        -0.012010   0.118624
# url_longest_dom_token_len               -0.008084  -0.509985
# url_average_dom_token_len               -0.004599  -0.534915
# url_tld                                 -0.006469  -0.195497
# url_domain_len                          -0.003609  -0.383381
# url_hostname_len                        -0.004364  -0.387142
# url_num_dots                            -0.024506   0.039950
# url_num_underscores                     -0.009406   0.114572
# url_num_equals                          -0.000842  -0.193610
# url_num_slashes                         -0.014440  -0.142931
# url_num_dash                             0.008680  -0.181687
# url_num_semicolon                       -0.003889  -0.064152
# url_num_at                              -0.004633  -0.076415
# url_num_percent                         -0.008218   0.122109
# url_num_plus                            -0.002648   0.000479
# url_query_len                           -0.004718  -0.169771
# url_num_query_para                      -0.005218  -0.180959
# url_ip_present                          -0.004195   0.070428
# url_entropy                             -0.028443  -0.170543
# url_count_consonants                    -0.011095  -0.133337
# url_num_digits                          -0.005824   0.077680
# url_chinese_present                           NaN        NaN
# url_port                                 0.076772   0.004197
# html_num_tags('iframe')                  0.007298   0.042297
# html_num_tags('script')                  0.027727   0.205229
# html_num_tags('embed')                  -0.007402   0.104836
# html_num_tags('object')                  0.391428   0.103065
# html_num_tags('div')                     0.009090   0.063874
# html_num_tags('head')                   -0.000202  -0.035772
# html_num_tags('body')                   -0.004660  -0.112924
# html_num_tags('form')                    0.106033  -0.124800
# html_num_tags('a')                       0.024944   0.115747
# html_num_tags('small')                   0.026609   0.022192
# html_num_tags('span')                    0.002889   0.053305
# html_num_tags('input')                   0.021717  -0.199075
# html_num_tags('applet')                       NaN        NaN
# html_num_tags('img')                     0.000748   0.139923
# html_num_tags('video')                   0.549091   0.006198
# html_num_tags('audio')                   1.000000   0.013208
# Result_v1                                0.013208   1.000000
#
# [44 rows x 44 columns]

# %%
df.corr()['Result_v1'].sort_values(ascending=False)
# Out:
# Result_v1                    1.000000
# url_num_dom_token            0.242202
# html_num_tags('script')      0.205229
# html_num_tags('img')         0.139923
# url_num_percent              0.122109
# url_filename_len             0.118624
# html_num_tags('a')           0.115747
# url_num_underscores          0.114572
# html_num_tags('embed')       0.104836
# url_path_len                 0.103433
# html_num_tags('object')      0.103065
# url_num_digits               0.077680
# url_ip_present               0.070428
# html_num_tags('div')         0.063874
# html_num_tags('span')        0.053305
# html_num_tags('iframe')      0.042297
# url_num_dots                 0.039950
# html_num_tags('small')       0.022192
# html_num_tags('audio')       0.013208
# html_num_tags('video')       0.006198
# url_port                     0.004197
# url_num_plus                 0.000479
# url_len                     -0.005050
# html_num_tags('head')       -0.035772
# url_num_semicolon           -0.064152
# url_num_at                  -0.076415
# html_num_tags('body')       -0.112924
# html_num_tags('form')       -0.124800
# url_count_consonants        -0.133337
# url_num_slashes             -0.142931
# url_query_len               -0.169771
# url_entropy                 -0.170543
# url_num_query_para          -0.180959
# url_num_dash                -0.181687
# url_num_equals              -0.193610
# url_tld                     -0.195497
# html_num_tags('input')      -0.199075
# url_num_hyphens_dom         -0.362520
# url_domain_len              -0.383381
# url_hostname_len            -0.387142
# url_longest_dom_token_len   -0.509985
# url_average_dom_token_len   -0.534915
# url_chinese_present               NaN
# html_num_tags('applet')           NaN
# Name: Result_v1, dtype: float64

# %% [markdown]
# #### <b>scatter 그래프를 활용한 데이터 분석 실습</b>
# ---

# %%
import matplotlib.pyplot as plt

# %%
# 1 = 'blue',-1 = 'red' 처리
df['color'] = df['Result_v1'].map({1:"blue", -1:"red"})

# %% [markdown]
# df

# %%
y_list = df.columns

for i in range(0, len(y_list)):
    df.plot(kind='scatter',x='Result_v1',y=y_list[i],s=30, c=df['color'])
    plt.title('Scatter Benign Malicious', fontsize=20)
    plt.xlabel('Result_v1')
    plt.ylabel(y_list[i])
    plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### <b>불필요한 컬럼 제거</b>
# ---

# %%
df.drop(columns=["url_chinese_present","html_num_tags('applet')"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5189 entries, 0 to 5999
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url_len                    5189 non-null   int64
#  1   url_num_hyphens_dom        5189 non-null   int64
#  2   url_num_dom_token          5189 non-null   float64
#  3   url_path_len               5189 non-null   float64
#  4   url_filename_len           5189 non-null   int64
#  5   url_longest_dom_token_len  5189 non-null   int64
#  6   url_average_dom_token_len  5189 non-null   float64
#  7   url_tld                    5189 non-null   int64
#  8   url_domain_len             5189 non-null   float64
#  9   url_hostname_len           5189 non-null   int64
#  10  url_num_dots               5189 non-null   int64
#  11  url_num_underscores        5189 non-null   float64
#  12  url_num_equals             5189 non-null   float64
#  13  url_num_slashes            5189 non-null   float64
#  14  url_num_dash               5189 non-null   int64
#  15  url_num_semicolon          5189 non-null   int64
#  16  url_num_at                 5189 non-null   int64
#  17  url_num_percent            5189 non-null   int64
#  18  url_num_plus               5189 non-null   int64
#  19  url_query_len              5189 non-null   int64
#  20  url_num_query_para         5189 non-null   int64
#  21  url_ip_present             5189 non-null   int64
#  22  url_entropy                5189 non-null   float64
#  23  url_count_consonants       5189 non-null   int64
#  24  url_num_digits             5189 non-null   int64
#  25  url_port                   5189 non-null   int64
#  26  html_num_tags('iframe')    5189 non-null   int64
#  27  html_num_tags('script')    5189 non-null   int64
#  28  html_num_tags('embed')     5189 non-null   int64
#  29  html_num_tags('object')    5189 non-null   int64
#  30  html_num_tags('div')       5189 non-null   int64
#  31  html_num_tags('head')      5189 non-null   int64
#  32  html_num_tags('body')      5189 non-null   int64
#  33  html_num_tags('form')      5189 non-null   int64
#  34  html_num_tags('a')         5189 non-null   int64
#  35  html_num_tags('small')     5189 non-null   int64
#  36  html_num_tags('span')      5189 non-null   int64
#  37  html_num_tags('input')     5189 non-null   int64
#  38  html_num_tags('img')       5189 non-null   int64
#  39  html_num_tags('video')     5189 non-null   int64
#  40  html_num_tags('audio')     5189 non-null   int64
#  41  Result_v1                  5189 non-null   int64
#  42  color                      5189 non-null   object
# dtypes: float64(8), int64(34), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Q5. train_test_split을 이용하여, train_x, val_x, train_y, val_y로 데이터 분리
# ---
#
# - test_size = 0.3
# - random_state = 2021

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:,0:len(df.columns)-1].values
y = df.iloc[:,len(df.columns)-1].values

# %%
# train_test_split 사용
train_x, val_x, train_y, val_y = train_test_split(X, y,test_size=0.3,random_state=2021)

# %%
train_x.shape, val_x.shape, train_y.shape, val_y.shape
# Out:
# ((3632, 42), (1557, 42), (3632,), (1557,))
