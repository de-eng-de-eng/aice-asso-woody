# %%
pip install bs4
# Out:
# Looking in indexes: http://10.220.235.19/pypi/simple
# Requirement already satisfied: bs4 in /usr/local/lib/python3.6/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from bs4) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.6/dist-packages (from beautifulsoup4->bs4) (2.0.1)
# WARNING: You are using pip version 20.1; however, version 20.2.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.parse import urlparse

from aicentro.session import Session
sacp_session = Session(verify=False)
from aicentro.framework.framework import BaseFramework as SacpFrm
sacp_framework = SacpFrm(session=sacp_session)

# %% [markdown]
# ### <b>Q1. 데이터 불러오기</b>
# ---
# - Feature Website.xlsx 데이터 불러오기
# - 데이터 둘러보기

# %%
filename ='      '
#xlrd 지원불가로 openpyxl 사용할 수 있도록 변경
df = pd.read_excel(filename, engine='openpyxl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   html_code  40 non-null     object
#  1   repu       40 non-null     object
# dtypes: object(2)
# memory usage: 768.0+ bytes

# %%
df
# Out:
#                                             html_code       repu
# 0   <!DOCTYPE html>\n<!--[if lt IE 7]> <html lang=...  malicious
# 1   \n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t...  malicious
# 2   <!DOCTYPE html>\n<html lang="en">\n    <head>\...  malicious
# 3   <!DOCTYPE html><html lang="en"><head><style da...  malicious
# 4   <!DOCTYPE html>\n\n\n    \n    \n    \n    \n ...  malicious
# 5   \r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko-...  malicious
# 6   <!doctype html>\n\n<html data-ytrk-page="HOME"...  malicious
# 7   \n\t<!DOCTYPE html>\n\t<html class="no-icon-fo...  malicious
# 8   <!DOCTYPE html>\n<html class="no-js">\n<head>\...  malicious
# 9       <!DOCTYPE html>\n<html class="b-header--bl...  malicious
# 10  <!DOCTYPE html>\n<html lang="mul" dir="ltr">\n...  malicious
# 11  \r\n\r\n<!DOCTYPE html><html lang="en" itemsco...  malicious
# 12  <!DOCTYPE html><html lang="en"><head><link rel...  malicious
# 13  <!Doctype html>\r\n<html> \r\n<head>\r\n<title...  malicious
# 14  <html lang="en">\n\n<head>\n    <title>Verify ...  malicious
# 15  <!doctype html><html dir="ltr" lang="ko-KR"><h...  malicious
# 16  <HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</...  malicious
# 17  <!doctype html>\r\n<html xmlns="http://www.w3....  malicious
# 18  \r\n<!DOCTYPE html>\r\n\r\n<html lang="en">\r\...  malicious
# 19  <!DOCTYPE html><html lang=en><head><meta http-...  malicious
# 20  <!DOCTYPE html><html lang="en"><head><style da...     benign
# 21  <!doctype html><html lang="en"><head><title da...     benign
# 22  <!DOCTYPE html>\n<!--[if lt IE 8]>      <html ...     benign
# 23  \n<!DOCTYPE html>\n<html id="js-context" class...     benign
# 24  <!DOCTYPE html><html class="no-js"><head><meta...     benign
# 25  \r\n\r\n\r\n<!DOCTYPE html>\r\n<!--[if IE 8]><...     benign
# 26  <!DOCTYPE html>\r\n<html class=" responsive" l...     benign
# 27  <!DOCTYPE html><html lang="en"><head><meta cha...     benign
# 28  <!DOCTYPE html>\n<html lang="en" xmlns:og="htt...     benign
# 29  \n<!DOCTYPE HTML>\n<html lang="ko-KR" xml:lang...     benign
# 30  <!DOCTYPE html>\n<html lang="en">\n<head>\n  <...     benign
# 31  <!DOCTYPE html>\n<html lang="pt-BR"> <head><ti...     benign
# 32  \n<!DOCTYPE HTML>\n\n<html ng-app="usr" class=...     benign
# 33  <!DOCTYPE html>\n<html lang="en" dir="ltr" dat...     benign
# 34  <!DOCTYPE html><html lang="en" itemscope="" it...     benign
# 35  \n\n\n    <!DOCTYPE HTML>\n    <html class="sp...     benign
# 36  <!doctype html>\n<html lang="en"><head><meta h...     benign
# 37  \n\n\n\t<!DOCTYPE html>\n\t<html class="no-js"...     benign
# 38  \r\n<!DOCTYPE HTML>\r\n<html>\r\n<head><meta h...     benign
# 39  <!DOCTYPE html>\n<html>\n\n<head>\n  <title>Bu...     benign

# %% [markdown]
# ### <b>Q2. html 에서 \<script>...\</script> 길이 계산</b>
# ---
# - BeautifulSoup으로 html소스를 python 객체로 변환
# - 함수로 구현하기
# - float으로 return 받기

# %%
def html_script_characters(soup):
    # soup > script
    html_len = str(soup.script)
    return float(len(html_len.replace(' ', '')))

# %%
script_len = []

for index, row in df.iterrows():
    soup = BeautifulSoup(row.html_code, 'html.parser')
    script_len.append(html_script_characters(soup))

df['html_script_characters'] = script_len

# %%
df
# Out:
#                                             html_code       repu  \
# 0   <!DOCTYPE html>\n<!--[if lt IE 7]> <html lang=...  malicious
# 1   \n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t...  malicious
# 2   <!DOCTYPE html>\n<html lang="en">\n    <head>\...  malicious
# 3   <!DOCTYPE html><html lang="en"><head><style da...  malicious
# 4   <!DOCTYPE html>\n\n\n    \n    \n    \n    \n ...  malicious
# 5   \r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko-...  malicious
# 6   <!doctype html>\n\n<html data-ytrk-page="HOME"...  malicious
# 7   \n\t<!DOCTYPE html>\n\t<html class="no-icon-fo...  malicious
# 8   <!DOCTYPE html>\n<html class="no-js">\n<head>\...  malicious
# 9       <!DOCTYPE html>\n<html class="b-header--bl...  malicious
# 10  <!DOCTYPE html>\n<html lang="mul" dir="ltr">\n...  malicious
# 11  \r\n\r\n<!DOCTYPE html><html lang="en" itemsco...  malicious
# 12  <!DOCTYPE html><html lang="en"><head><link rel...  malicious
# 13  <!Doctype html>\r\n<html> \r\n<head>\r\n<title...  malicious
# 14  <html lang="en">\n\n<head>\n    <title>Verify ...  malicious
# 15  <!doctype html><html dir="ltr" lang="ko-KR"><h...  malicious
# 16  <HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</...  malicious
# 17  <!doctype html>\r\n<html xmlns="http://www.w3....  malicious
# 18  \r\n<!DOCTYPE html>\r\n\r\n<html lang="en">\r\...  malicious
# 19  <!DOCTYPE html><html lang=en><head><meta http-...  malicious
# 20  <!DOCTYPE html><html lang="en"><head><style da...     benign
# 21  <!doctype html><html lang="en"><head><title da...     benign
# 22  <!DOCTYPE html>\n<!--[if lt IE 8]>      <html ...     benign
# 23  \n<!DOCTYPE html>\n<html id="js-context" class...     benign
# 24  <!DOCTYPE html><html class="no-js"><head><meta...     benign
# 25  \r\n\r\n\r\n<!DOCTYPE html>\r\n<!--[if IE 8]><...     benign
# 26  <!DOCTYPE html>\r\n<html class=" responsive" l...     benign
# 27  <!DOCTYPE html><html lang="en"><head><meta cha...     benign
# 28  <!DOCTYPE html>\n<html lang="en" xmlns:og="htt...     benign
# 29  \n<!DOCTYPE HTML>\n<html lang="ko-KR" xml:lang...     benign
# 30  <!DOCTYPE html>\n<html lang="en">\n<head>\n  <...     benign
# 31  <!DOCTYPE html>\n<html lang="pt-BR"> <head><ti...     benign
# 32  \n<!DOCTYPE HTML>\n\n<html ng-app="usr" class=...     benign
# 33  <!DOCTYPE html>\n<html lang="en" dir="ltr" dat...     benign
# 34  <!DOCTYPE html><html lang="en" itemscope="" it...     benign
# 35  \n\n\n    <!DOCTYPE HTML>\n    <html class="sp...     benign
# 36  <!doctype html>\n<html lang="en"><head><meta h...     benign
# 37  \n\n\n\t<!DOCTYPE html>\n\t<html class="no-js"...     benign
# 38  \r\n<!DOCTYPE HTML>\r\n<html>\r\n<head><meta h...     benign
# 39  <!DOCTYPE html>\n<html>\n\n<head>\n  <title>Bu...     benign
#
#     html_script_characters
# 0                    308.0
# 1                    543.0
# 2                    492.0
# 3                      4.0
# 4                    312.0
# 5                   3125.0
# 6                   4793.0
# 7                    155.0
# 8                   1022.0
# 9                     82.0
# 10                   158.0
# 11                   226.0
# 12                  1500.0
# 13                  1046.0
# 14                   360.0
# 15                  8871.0
# 16                     4.0
# 17                   200.0
# 18                   190.0
# 19                    88.0
# 20                     4.0
# 21                     4.0
# 22                   325.0
# 23                   428.0
# 24                   165.0
# 25                   508.0
# 26                   620.0
# 27                    83.0
# 28                   179.0
# 29                   149.0
# 30                  1389.0
# 31                   400.0
# 32                   150.0
# 33                  1387.0
# 34                     4.0
# 35                  5555.0
# 36                     4.0
# 37                     4.0
# 38                   117.0
# 39                   262.0

# %%
df.describe()
# Out:
#        html_script_characters
# count                40.00000
# mean                880.40000
# std                1767.67696
# min                   4.00000
# 25%                 109.75000
# 50%                 244.00000
# 75%                 562.25000
# max                8871.00000

# %% [markdown]
# ### <b>Q3. html에서 공백 수 계산</b>
# ---
# - BeautifulSoup으로 html소스를 python 객체로 변환
# - 함수로 구현하기
# - float으로 return 받기

# %%
def html_num_whitespace(soup):
    try:
        # soup > body > text > count
        NullCount = 
        return float(NullCount)
    except:
        return 0.0

# %%
num_whitespace = []

for index, row in df.iterrows():
    soup = 
    num_whitespace.append(html_num_whitespace(soup))

df['html_num_whitespace'] = num_whitespace

# %%
df
# Out:
#                                             html_code       repu  \
# 0   <!DOCTYPE html>\n<!--[if lt IE 7]> <html lang=...  malicious
# 1   \n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t...  malicious
# 2   <!DOCTYPE html>\n<html lang="en">\n    <head>\...  malicious
# 3   <!DOCTYPE html><html lang="en"><head><style da...  malicious
# 4   <!DOCTYPE html>\n\n\n    \n    \n    \n    \n ...  malicious
# 5   \r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko-...  malicious
# 6   <!doctype html>\n\n<html data-ytrk-page="HOME"...  malicious
# 7   \n\t<!DOCTYPE html>\n\t<html class="no-icon-fo...  malicious
# 8   <!DOCTYPE html>\n<html class="no-js">\n<head>\...  malicious
# 9       <!DOCTYPE html>\n<html class="b-header--bl...  malicious
# 10  <!DOCTYPE html>\n<html lang="mul" dir="ltr">\n...  malicious
# 11  \r\n\r\n<!DOCTYPE html><html lang="en" itemsco...  malicious
# 12  <!DOCTYPE html><html lang="en"><head><link rel...  malicious
# 13  <!Doctype html>\r\n<html> \r\n<head>\r\n<title...  malicious
# 14  <html lang="en">\n\n<head>\n    <title>Verify ...  malicious
# 15  <!doctype html><html dir="ltr" lang="ko-KR"><h...  malicious
# 16  <HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</...  malicious
# 17  <!doctype html>\r\n<html xmlns="http://www.w3....  malicious
# 18  \r\n<!DOCTYPE html>\r\n\r\n<html lang="en">\r\...  malicious
# 19  <!DOCTYPE html><html lang=en><head><meta http-...  malicious
# 20  <!DOCTYPE html><html lang="en"><head><style da...     benign
# 21  <!doctype html><html lang="en"><head><title da...     benign
# 22  <!DOCTYPE html>\n<!--[if lt IE 8]>      <html ...     benign
# 23  \n<!DOCTYPE html>\n<html id="js-context" class...     benign
# 24  <!DOCTYPE html><html class="no-js"><head><meta...     benign
# 25  \r\n\r\n\r\n<!DOCTYPE html>\r\n<!--[if IE 8]><...     benign
# 26  <!DOCTYPE html>\r\n<html class=" responsive" l...     benign
# 27  <!DOCTYPE html><html lang="en"><head><meta cha...     benign
# 28  <!DOCTYPE html>\n<html lang="en" xmlns:og="htt...     benign
# 29  \n<!DOCTYPE HTML>\n<html lang="ko-KR" xml:lang...     benign
# 30  <!DOCTYPE html>\n<html lang="en">\n<head>\n  <...     benign
# 31  <!DOCTYPE html>\n<html lang="pt-BR"> <head><ti...     benign
# 32  \n<!DOCTYPE HTML>\n\n<html ng-app="usr" class=...     benign
# 33  <!DOCTYPE html>\n<html lang="en" dir="ltr" dat...     benign
# 34  <!DOCTYPE html><html lang="en" itemscope="" it...     benign
# 35  \n\n\n    <!DOCTYPE HTML>\n    <html class="sp...     benign
# 36  <!doctype html>\n<html lang="en"><head><meta h...     benign
# 37  \n\n\n\t<!DOCTYPE html>\n\t<html class="no-js"...     benign
# 38  \r\n<!DOCTYPE HTML>\r\n<html>\r\n<head><meta h...     benign
# 39  <!DOCTYPE html>\n<html>\n\n<head>\n  <title>Bu...     benign
#
#     html_script_characters  html_num_whitespace
# 0                    308.0                 65.0
# 1                    543.0                 87.0
# 2                    492.0                190.0
# 3                      4.0                  0.0
# 4                    312.0               1802.0
# 5                   3125.0                  0.0
# 6                   4793.0                153.0
# 7                    155.0                  0.0
# 8                   1022.0                 86.0
# 9                     82.0                  0.0
# 10                   158.0                116.0
# 11                   226.0                163.0
# 12                  1500.0                  0.0
# 13                  1046.0                219.0
# 14                   360.0                 56.0
# 15                  8871.0                  0.0
# 16                     4.0                 12.0
# 17                   200.0                550.0
# 18                   190.0                 45.0
# 19                    88.0                226.0
# 20                     4.0                  0.0
# 21                     4.0                  0.0
# 22                   325.0                 44.0
# 23                   428.0                  0.0
# 24                   165.0                  0.0
# 25                   508.0                  0.0
# 26                   620.0                 79.0
# 27                    83.0                 68.0
# 28                   179.0                  0.0
# 29                   149.0                 48.0
# 30                  1389.0                  0.0
# 31                   400.0                  0.0
# 32                   150.0                157.0
# 33                  1387.0                  0.0
# 34                     4.0                  0.0
# 35                  5555.0                  0.0
# 36                     4.0                  0.0
# 37                     4.0                  0.0
# 38                   117.0                 89.0
# 39                   262.0                  0.0

# %%
df.describe()
# Out:
#        html_script_characters  html_num_whitespace
# count                40.00000            40.000000
# mean                880.40000           106.375000
# std                1767.67696           293.861095
# min                   4.00000             0.000000
# 25%                 109.75000             0.000000
# 50%                 244.00000             6.000000
# 75%                 562.25000            87.500000
# max                8871.00000          1802.000000

# %% [markdown]
# ### <b>Q4. html 에서 body 길이 계산</b>
# ---
# - BeautifulSoup으로 html소스를 python 객체로 변환
# - 함수로 구현하기
# - float으로 return 받기

# %%
def html_num_characters(soup):
    try:
        #soup > body > text
        bodyLen = len(      )
        return float(bodyLen)
    except:
        return 0.0

# %%
html_body = []

for index, row in df.iterrows():
    soup =  
    html_body.append(html_num_characters(soup))

df['html_body_len'] = html_body

# %%
df
# Out:
#                                             html_code       repu  \
# 0   <!DOCTYPE html>\n<!--[if lt IE 7]> <html lang=...  malicious
# 1   \n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t...  malicious
# 2   <!DOCTYPE html>\n<html lang="en">\n    <head>\...  malicious
# 3   <!DOCTYPE html><html lang="en"><head><style da...  malicious
# 4   <!DOCTYPE html>\n\n\n    \n    \n    \n    \n ...  malicious
# 5   \r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko-...  malicious
# 6   <!doctype html>\n\n<html data-ytrk-page="HOME"...  malicious
# 7   \n\t<!DOCTYPE html>\n\t<html class="no-icon-fo...  malicious
# 8   <!DOCTYPE html>\n<html class="no-js">\n<head>\...  malicious
# 9       <!DOCTYPE html>\n<html class="b-header--bl...  malicious
# 10  <!DOCTYPE html>\n<html lang="mul" dir="ltr">\n...  malicious
# 11  \r\n\r\n<!DOCTYPE html><html lang="en" itemsco...  malicious
# 12  <!DOCTYPE html><html lang="en"><head><link rel...  malicious
# 13  <!Doctype html>\r\n<html> \r\n<head>\r\n<title...  malicious
# 14  <html lang="en">\n\n<head>\n    <title>Verify ...  malicious
# 15  <!doctype html><html dir="ltr" lang="ko-KR"><h...  malicious
# 16  <HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</...  malicious
# 17  <!doctype html>\r\n<html xmlns="http://www.w3....  malicious
# 18  \r\n<!DOCTYPE html>\r\n\r\n<html lang="en">\r\...  malicious
# 19  <!DOCTYPE html><html lang=en><head><meta http-...  malicious
# 20  <!DOCTYPE html><html lang="en"><head><style da...     benign
# 21  <!doctype html><html lang="en"><head><title da...     benign
# 22  <!DOCTYPE html>\n<!--[if lt IE 8]>      <html ...     benign
# 23  \n<!DOCTYPE html>\n<html id="js-context" class...     benign
# 24  <!DOCTYPE html><html class="no-js"><head><meta...     benign
# 25  \r\n\r\n\r\n<!DOCTYPE html>\r\n<!--[if IE 8]><...     benign
# 26  <!DOCTYPE html>\r\n<html class=" responsive" l...     benign
# 27  <!DOCTYPE html><html lang="en"><head><meta cha...     benign
# 28  <!DOCTYPE html>\n<html lang="en" xmlns:og="htt...     benign
# 29  \n<!DOCTYPE HTML>\n<html lang="ko-KR" xml:lang...     benign
# 30  <!DOCTYPE html>\n<html lang="en">\n<head>\n  <...     benign
# 31  <!DOCTYPE html>\n<html lang="pt-BR"> <head><ti...     benign
# 32  \n<!DOCTYPE HTML>\n\n<html ng-app="usr" class=...     benign
# 33  <!DOCTYPE html>\n<html lang="en" dir="ltr" dat...     benign
# 34  <!DOCTYPE html><html lang="en" itemscope="" it...     benign
# 35  \n\n\n    <!DOCTYPE HTML>\n    <html class="sp...     benign
# 36  <!doctype html>\n<html lang="en"><head><meta h...     benign
# 37  \n\n\n\t<!DOCTYPE html>\n\t<html class="no-js"...     benign
# 38  \r\n<!DOCTYPE HTML>\r\n<html>\r\n<head><meta h...     benign
# 39  <!DOCTYPE html>\n<html>\n\n<head>\n  <title>Bu...     benign
#
#     html_script_characters  html_num_whitespace  html_body_len
# 0                    308.0                 65.0          402.0
# 1                    543.0                 87.0         1041.0
# 2                    492.0                190.0          433.0
# 3                      4.0                  0.0            0.0
# 4                    312.0               1802.0         2969.0
# 5                   3125.0                  0.0            0.0
# 6                   4793.0                153.0          779.0
# 7                    155.0                  0.0            0.0
# 8                   1022.0                 86.0         2032.0
# 9                     82.0                  0.0            0.0
# 10                   158.0                116.0         2733.0
# 11                   226.0                163.0          888.0
# 12                  1500.0                  0.0            0.0
# 13                  1046.0                219.0         2570.0
# 14                   360.0                 56.0          273.0
# 15                  8871.0                  0.0            0.0
# 16                     4.0                 12.0          139.0
# 17                   200.0                550.0         4297.0
# 18                   190.0                 45.0          384.0
# 19                    88.0                226.0         3047.0
# 20                     4.0                  0.0            0.0
# 21                     4.0                  0.0            0.0
# 22                   325.0                 44.0          854.0
# 23                   428.0                  0.0            0.0
# 24                   165.0                  0.0            0.0
# 25                   508.0                  0.0            0.0
# 26                   620.0                 79.0         1375.0
# 27                    83.0                 68.0         1078.0
# 28                   179.0                  0.0            0.0
# 29                   149.0                 48.0          322.0
# 30                  1389.0                  0.0            4.0
# 31                   400.0                  0.0            0.0
# 32                   150.0                157.0          865.0
# 33                  1387.0                  0.0            0.0
# 34                     4.0                  0.0            0.0
# 35                  5555.0                  0.0           24.0
# 36                     4.0                  0.0            0.0
# 37                     4.0                  0.0            0.0
# 38                   117.0                 89.0         1652.0
# 39                   262.0                  0.0            0.0

# %%
df.describe()
# Out:
#        html_script_characters  html_num_whitespace  html_body_len
# count                40.00000            40.000000      40.000000
# mean                880.40000           106.375000     704.025000
# std                1767.67696           293.861095    1078.622566
# min                   4.00000             0.000000       0.000000
# 25%                 109.75000             0.000000       0.000000
# 50%                 244.00000             6.000000      81.500000
# 75%                 562.25000            87.500000     926.250000
# max                8871.00000          1802.000000    4297.000000

# %% [markdown]
# ### <b> Q5. script 에서 src, href 속성을 가진 태그수</b>
# 1. BeautifulSoup으로 html소스를 python 객체로 변환
# 2. 함수로 구현하기
# 3. float으로 return 받기

# %%
def html_link_in_script(soup):
    numOfLinks = len(soup.findAll('script', {"src": True}))
    numOfLinks += len(           ('      ', {"   ": True}))
    return float(numOfLinks)

# %%
html_script_link_num = []

for index, row in df.iterrows():
    soup =  
    html_script_link_num.append(html_link_in_script(soup))

df['html_script_link_num'] = html_script_link_num

# %%
df
# Out:
#                                             html_code       repu  \
# 0   <!DOCTYPE html>\n<!--[if lt IE 7]> <html lang=...  malicious
# 1   \n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t...  malicious
# 2   <!DOCTYPE html>\n<html lang="en">\n    <head>\...  malicious
# 3   <!DOCTYPE html><html lang="en"><head><style da...  malicious
# 4   <!DOCTYPE html>\n\n\n    \n    \n    \n    \n ...  malicious
# 5   \r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko-...  malicious
# 6   <!doctype html>\n\n<html data-ytrk-page="HOME"...  malicious
# 7   \n\t<!DOCTYPE html>\n\t<html class="no-icon-fo...  malicious
# 8   <!DOCTYPE html>\n<html class="no-js">\n<head>\...  malicious
# 9       <!DOCTYPE html>\n<html class="b-header--bl...  malicious
# 10  <!DOCTYPE html>\n<html lang="mul" dir="ltr">\n...  malicious
# 11  \r\n\r\n<!DOCTYPE html><html lang="en" itemsco...  malicious
# 12  <!DOCTYPE html><html lang="en"><head><link rel...  malicious
# 13  <!Doctype html>\r\n<html> \r\n<head>\r\n<title...  malicious
# 14  <html lang="en">\n\n<head>\n    <title>Verify ...  malicious
# 15  <!doctype html><html dir="ltr" lang="ko-KR"><h...  malicious
# 16  <HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</...  malicious
# 17  <!doctype html>\r\n<html xmlns="http://www.w3....  malicious
# 18  \r\n<!DOCTYPE html>\r\n\r\n<html lang="en">\r\...  malicious
# 19  <!DOCTYPE html><html lang=en><head><meta http-...  malicious
# 20  <!DOCTYPE html><html lang="en"><head><style da...     benign
# 21  <!doctype html><html lang="en"><head><title da...     benign
# 22  <!DOCTYPE html>\n<!--[if lt IE 8]>      <html ...     benign
# 23  \n<!DOCTYPE html>\n<html id="js-context" class...     benign
# 24  <!DOCTYPE html><html class="no-js"><head><meta...     benign
# 25  \r\n\r\n\r\n<!DOCTYPE html>\r\n<!--[if IE 8]><...     benign
# 26  <!DOCTYPE html>\r\n<html class=" responsive" l...     benign
# 27  <!DOCTYPE html><html lang="en"><head><meta cha...     benign
# 28  <!DOCTYPE html>\n<html lang="en" xmlns:og="htt...     benign
# 29  \n<!DOCTYPE HTML>\n<html lang="ko-KR" xml:lang...     benign
# 30  <!DOCTYPE html>\n<html lang="en">\n<head>\n  <...     benign
# 31  <!DOCTYPE html>\n<html lang="pt-BR"> <head><ti...     benign
# 32  \n<!DOCTYPE HTML>\n\n<html ng-app="usr" class=...     benign
# 33  <!DOCTYPE html>\n<html lang="en" dir="ltr" dat...     benign
# 34  <!DOCTYPE html><html lang="en" itemscope="" it...     benign
# 35  \n\n\n    <!DOCTYPE HTML>\n    <html class="sp...     benign
# 36  <!doctype html>\n<html lang="en"><head><meta h...     benign
# 37  \n\n\n\t<!DOCTYPE html>\n\t<html class="no-js"...     benign
# 38  \r\n<!DOCTYPE HTML>\r\n<html>\r\n<head><meta h...     benign
# 39  <!DOCTYPE html>\n<html>\n\n<head>\n  <title>Bu...     benign
#
#     html_script_characters  html_num_whitespace  html_body_len  \
# 0                    308.0                 65.0          402.0
# 1                    543.0                 87.0         1041.0
# 2                    492.0                190.0          433.0
# 3                      4.0                  0.0            0.0
# 4                    312.0               1802.0         2969.0
# 5                   3125.0                  0.0            0.0
# 6                   4793.0                153.0          779.0
# 7                    155.0                  0.0            0.0
# 8                   1022.0                 86.0         2032.0
# 9                     82.0                  0.0            0.0
# 10                   158.0                116.0         2733.0
# 11                   226.0                163.0          888.0
# 12                  1500.0                  0.0            0.0
# 13                  1046.0                219.0         2570.0
# 14                   360.0                 56.0          273.0
# 15                  8871.0                  0.0            0.0
# 16                     4.0                 12.0          139.0
# 17                   200.0                550.0         4297.0
# 18                   190.0                 45.0          384.0
# 19                    88.0                226.0         3047.0
# 20                     4.0                  0.0            0.0
# 21                     4.0                  0.0            0.0
# 22                   325.0                 44.0          854.0
# 23                   428.0                  0.0            0.0
# 24                   165.0                  0.0            0.0
# 25                   508.0                  0.0            0.0
# 26                   620.0                 79.0         1375.0
# 27                    83.0                 68.0         1078.0
# 28                   179.0                  0.0            0.0
# 29                   149.0                 48.0          322.0
# 30                  1389.0                  0.0            4.0
# 31                   400.0                  0.0            0.0
# 32                   150.0                157.0          865.0
# 33                  1387.0                  0.0            0.0
# 34                     4.0                  0.0            0.0
# 35                  5555.0                  0.0           24.0
# 36                     4.0                  0.0            0.0
# 37                     4.0                  0.0            0.0
# 38                   117.0                 89.0         1652.0
# 39                   262.0                  0.0            0.0
#
#     html_script_link_num
# 0                    0.0
# 1                    4.0
# 2                    8.0
# 3                    0.0
# 4                    0.0
# 5                    0.0
# 6                    6.0
# 7                    4.0
# 8                    0.0
# 9                    1.0
# 10                   1.0
# 11                   0.0
# 12                   1.0
# 13                   1.0
# 14                   0.0
# 15                   0.0
# 16                   0.0
# 17                   4.0
# 18                   2.0
# 19                   2.0
# 20                   0.0
# 21                   0.0
# 22                   2.0
# 23                   0.0
# 24                   0.0
# 25                   6.0
# 26                   9.0
# 27                   1.0
# 28                   2.0
# 29                  11.0
# 30                   3.0
# 31                   4.0
# 32                   3.0
# 33                   2.0
# 34                   0.0
# 35                   4.0
# 36                   0.0
# 37                   0.0
# 38                  10.0
# 39                   4.0

# %%
df.describe()
# Out:
#        html_script_characters  html_num_whitespace  html_body_len  \
# count                40.00000            40.000000      40.000000
# mean                880.40000           106.375000     704.025000
# std                1767.67696           293.861095    1078.622566
# min                   4.00000             0.000000       0.000000
# 25%                 109.75000             0.000000       0.000000
# 50%                 244.00000             6.000000      81.500000
# 75%                 562.25000            87.500000     926.250000
# max                8871.00000          1802.000000    4297.000000
#
#        html_script_link_num
# count             40.000000
# mean               2.375000
# std                3.001602
# min                0.000000
# 25%                0.000000
# 50%                1.000000
# 75%                4.000000
# max               11.000000
